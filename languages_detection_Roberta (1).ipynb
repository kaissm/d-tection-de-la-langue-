# %% [markdown]
# 1. GPU Setup in Colab

# %%
import tensorflow as tf

# Get the GPU device name.
device_name = tf.test.gpu_device_name()

# The device name should look like the following:
if device_name == '/device:GPU:0':
    print('Found GPU at: {}'.format(device_name))
else:
    raise SystemError('GPU device not found')
# Out:
# Found GPU at: /device:GPU:0

# %%
import torch

# If there's a GPU available...
if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla K80

# %%
# !pip install transformers
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Collecting transformers
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 5.1 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 38.3 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 6.4 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 55.0 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 48.2 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.5.1 pyyaml-6.0 sacremoses-0.0.49 tokenizers-0.12.1 transformers-4.18.0

# %%
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
from transformers import RobertaModel, RobertaTokenizer
import logging
logging.basicConfig(level=logging.ERROR)

# %%
data = pd.read_excel('/content/data_Roberta.xlsx')
data1 = data[['phrase','prompt']]
data1.sample(5)
# Out:
#                                                   phrase        prompt
# 3764   إيران بلد أحبه منذ الصغر ...و باذن الله سأزوه ...         arabe
# 13258  خصووووصا إلى كانت درية لي هزاتها , أشمكن يا فا...   darij_arabe
# 17321                            blann makanch frassi 👌👌  darija_latin
# 12959                                     توال الكريّفات   darij_arabe
# 16051               نمشيو نعسو واحد شوية بينما توصل 3:00   darij_arabe

# %%
df=data1.copy()
df.isna().sum()
# Out:
# phrase    0
# prompt    0
# dtype: int64

# %%
df['prompt'].value_counts()
# Out:
# darij_arabe     5950
# darija_latin    4156
# francais        3932
# anglais         3677
# arabe           3604
# Name: prompt, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X, sentence_test, y, intent_test = train_test_split(df.phrase, df.prompt, stratify = df.prompt,test_size=0.2, random_state=4612)
sentence_train, sentence_val, intent_train, intent_val = train_test_split(X, y, stratify = y,test_size=0.125, random_state=4612)

# %%
TRAIN_BATCH_SIZE = 8
VALID_BATCH_SIZE = 4
EPSILON = 1e-08
EPOCHS = 4
LEARNING_RATE = 2e-5
SEED = 1215
tokenizer = RobertaTokenizer.from_pretrained('roberta-base', truncation=True, do_lower_case=True)
# Out:
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]

# %%
max_len = 0
input = []
length=[]
# For every sentence...
for sent in sentence_train:

    # Tokenize the text and add special tokens--`[CLS]` and `[SEP]` tokens.
    input_ids = tokenizer.encode(sent, add_special_tokens=True)
    input.append(input_ids)
    length.append(len(input_ids))
    # Update the maximum sentence length.
    max_len = max(max_len, len(input_ids))
    mean_len = sum(length)/len(length)
#39 tokens is the maximum number of tokens in a sentence (transcription). Also, a sentence has 14 tokens on average.
print('Max sentence length:%d \nMean sentence length:%d' % (max_len,mean_len))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (2420 > 512). Running this sequence through the model will result in indexing errors
# Max sentence length:5134
# Mean sentence length:52

# %%
def tokenize(sentence):
  batch = tokenizer(list(sentence),             
                  is_pretokenized=False,
                  #Pad or truncate all sentences to the same length. Create the attention masks which explicitly differentiate real tokens from [PAD] tokens.
                  padding=True, 
                  truncation=True,
                  return_tensors="pt")
  return batch

# %%
tok_train = tokenize(sentence_train)
tok_val = tokenize(sentence_val)
tok_test = tokenize(sentence_test)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# ...
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.
# Keyword arguments {'is_pretokenized': False} not recognized.

# %%
from sklearn.preprocessing import LabelEncoder
# encode "intent" to 25 number labels
LE = LabelEncoder()
label_train = torch.tensor((LE.fit_transform(intent_train)))
label_val = torch.tensor((LE.fit_transform(intent_val)))
label_test = torch.tensor((LE.fit_transform(intent_test)))

# %%
from torch.utils.data import TensorDataset

train_dataset = TensorDataset(tok_train['input_ids'], tok_train['attention_mask'],label_train)
validation_dataset = TensorDataset(tok_val['input_ids'], tok_val['attention_mask'],label_val)
test_dataset = TensorDataset(tok_test['input_ids'], tok_test['attention_mask'],label_test)

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

# Create the DataLoaders for our training and validation sets.
# We'll take training samples in random order. 
train_dataloader = DataLoader(
            train_dataset,  # The training samples.
            sampler = RandomSampler(train_dataset), # Select batches randomly
            batch_size = TRAIN_BATCH_SIZE # Trains with this batch size.
        )

# For validation/test the order doesn't matter, so we'll just read them sequentially.
validation_dataloader = DataLoader(
            validation_dataset, # The validation samples.
            sampler = SequentialSampler(validation_dataset), # Pull out batches sequentially.
            batch_size = VALID_BATCH_SIZE # Evaluate with this batch size.
        )

test_dataloader = DataLoader(
            validation_dataset, 
            sampler = SequentialSampler(validation_dataset), 
            batch_size = VALID_BATCH_SIZE 
        )

# %%
from transformers import BertForSequenceClassification, AdamW, BertConfig
from transformers import get_linear_schedule_with_warmup
## use pretained base(relatively small) BERT mdoel for sequence classification 
#CUDA_LAUNCH_BLOCKING=1
model = BertForSequenceClassification.from_pretrained('roberta-base', num_labels = 25)
model.cuda() # make pytorch run this model on GPU.

## use AdamW optimizer
optimizer = AdamW(model.parameters(), 
                  lr = LEARNING_RATE, 
                  eps = EPSILON  )


total_steps = len(train_dataloader) * EPOCHS


scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0, # Default value in run_glue.py
                                            num_training_steps = total_steps)
# Out:
# You are using a model of type roberta to instantiate a model of type bert. This is not supported for all configurations of models and can yield errors.
# Downloading:   0%|          | 0.00/478M [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing BertForSequenceClassification: ['roberta.encoder.layer.0.attention.self.value.weight', 'roberta.encoder.layer.8.attention.output.LayerNorm.weight', 'roberta.encoder.layer.4.attention.output.dense.weight', 'roberta.encoder.layer.9.attention.self.key.weight', 'roberta.encoder.layer.2.output.LayerNorm.weight', 'roberta.encoder.layer.7.attention.self.key.weight', 'roberta.encoder.layer.6.attention.self.key.bias', 'roberta.encoder.layer.10.attention.self.key.weight', 'roberta.encoder.layer.3.intermediate.dense.weight', 'roberta.encoder.layer.9.intermediate.dense.bias', 'roberta.encoder.layer.1.intermediate.dense.weight', 'roberta.encoder.layer.2.attention.self.query.bias', 'roberta.encoder.layer.7.attention.output.dense.bias', 'roberta.encoder.layer.0.output.LayerNorm.bias', 'roberta.encoder.layer.0.output.LayerNorm.weight', 'roberta.encoder.layer.8.output.LayerNorm.bias', 'roberta.encoder.layer.1.output.dense.bias', 'roberta.encoder.layer.1.attention.self.query.bias', 'roberta.embeddings.position_embeddings.weight', 'roberta.encoder.layer.8.attention.output.LayerNorm.bias', 'roberta.encoder.layer.1.attention.output.dense.bias', 'roberta.encoder.layer.4.attention.self.query.weight', 'roberta.encoder.layer.1.output.LayerNorm.weight', 'roberta.encoder.layer.5.attention.self.value.weight', 'roberta.encoder.layer.7.intermediate.dense.weight', 'roberta.encoder.layer.9.attention.output.dense.bias', 'roberta.encoder.layer.7.attention.self.key.bias', 'roberta.encoder.layer.4.attention.self.value.bias', 'roberta.encoder.layer.3.attention.output.dense.weight', 'roberta.encoder.layer.8.output.dense.bias', 'roberta.encoder.layer.8.attention.self.key.weight', 'roberta.encoder.layer.10.output.LayerNorm.bias', 'roberta.encoder.layer.10.output.dense.weight', 'roberta.encoder.layer.11.output.LayerNorm.bias', 'roberta.encoder.layer.6.attention.self.query.bias', 'roberta.encoder.layer.8.output.dense.weight', 'roberta.embeddings.token_type_embeddings.weight', 'roberta.embeddings.LayerNorm.weight', 'roberta.encoder.layer.0.output.dense.weight', 'roberta.encoder.layer.4.intermediate.dense.weight', 'roberta.pooler.dense.bias', 'roberta.encoder.layer.11.output.LayerNorm.weight', 'roberta.encoder.layer.7.attention.output.LayerNorm.bias', 'roberta.encoder.layer.0.intermediate.dense.bias', 'roberta.encoder.layer.6.attention.self.value.bias', 'roberta.encoder.layer.11.intermediate.dense.weight', 'roberta.encoder.layer.5.output.dense.weight', 'roberta.encoder.layer.4.intermediate.dense.bias', 'roberta.encoder.layer.1.attention.self.key.bias', 'roberta.encoder.layer.2.attention.self.key.weight', 'roberta.encoder.layer.9.output.dense.bias', 'roberta.encoder.layer.5.output.LayerNorm.bias', 'roberta.encoder.layer.7.attention.self.value.weight', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'roberta.encoder.layer.1.attention.output.LayerNorm.weight', 'roberta.encoder.layer.10.intermediate.dense.weight', 'roberta.encoder.layer.5.attention.self.value.bias', 'roberta.encoder.layer.6.output.dense.weight', 'roberta.encoder.layer.3.attention.self.query.weight', 'roberta.encoder.layer.4.attention.self.query.bias', 'roberta.encoder.layer.0.intermediate.dense.weight', 'roberta.encoder.layer.7.attention.output.LayerNorm.weight', 'roberta.encoder.layer.10.attention.output.LayerNorm.weight', 'roberta.encoder.layer.11.attention.self.value.weight', 'roberta.encoder.layer.4.attention.output.LayerNorm.bias', 'roberta.encoder.layer.2.attention.self.value.weight', 'roberta.encoder.layer.10.attention.output.dense.bias', 'roberta.encoder.layer.7.output.dense.weight', 'roberta.embeddings.word_embeddings.weight', 'roberta.encoder.layer.1.attention.self.key.weight', 'roberta.encoder.layer.1.attention.self.value.bias', 'roberta.encoder.layer.4.attention.output.LayerNorm.weight', 'roberta.encoder.layer.8.attention.self.value.bias', 'roberta.encoder.layer.2.attention.output.LayerNorm.bias', 'rober ...
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['encoder.layer.5.output.LayerNorm.bias', 'encoder.layer.0.intermediate.dense.weight', 'encoder.layer.8.output.dense.bias', 'encoder.layer.1.attention.output.dense.weight', 'encoder.layer.10.attention.self.key.weight', 'encoder.layer.3.output.LayerNorm.bias', 'encoder.layer.3.attention.self.value.bias', 'encoder.layer.9.intermediate.dense.weight', 'encoder.layer.11.attention.self.value.weight', 'encoder.layer.4.attention.output.LayerNorm.bias', 'encoder.layer.5.output.dense.bias', 'encoder.layer.5.attention.output.LayerNorm.weight', 'embeddings.LayerNorm.weight', 'encoder.layer.2.attention.output.dense.bias', 'encoder.layer.7.attention.self.value.weight', 'encoder.layer.10.attention.self.key.bias', 'encoder.layer.6.output.LayerNorm.bias', 'encoder.layer.6.attention.self.key.bias', 'encoder.layer.9.attention.self.key.bias', 'encoder.layer.11.attention.self.query.weight', 'encoder.layer.0.attention.self.value.weight', 'classifier.weight', 'encoder.layer.1.intermediate.dense.weight', 'encoder.layer.6.intermediate.dense.bias', 'encoder.layer.10.attention.self.query.weight', 'encoder.layer.9.output.LayerNorm.bias', 'encoder.layer.1.attention.self.value.weight', 'encoder.layer.6.attention.self.query.weight', 'encoder.layer.2.intermediate.dense.weight', 'encoder.layer.10.output.LayerNorm.bias', 'encoder.layer.9.attention.self.value.weight', 'encoder.layer.8.attention.self.value.bias', 'encoder.layer.7.output.dense.bias', 'encoder.layer.7.output.LayerNorm.bias', 'encoder.layer.4.attention.self.key.weight', 'encoder.layer.6.attention.output.LayerNorm.weight', 'pooler.dense.bias', 'encoder.layer.3.attention.self.value.weight', 'encoder.layer.0.output.dense.weight', 'encoder.layer.8.attention.self.key.bias', 'encoder.layer.10.attention.output.LayerNorm.bias', 'encoder.layer.11.attention.output.LayerNorm.bias', 'encoder.layer.5.attention.self.key.bias', 'encoder.layer.0.attention.output.dense.bias', 'encoder.layer.2.attention.self.query.weight', 'encoder.layer.4.output.LayerNorm.weight', 'encoder.layer.9.attention.self.value.bias', 'encoder.layer.8.attention.self.value.weight', 'encoder.layer.1.intermediate.dense.bias', 'encoder.layer.10.attention.self.value.bias', 'encoder.layer.5.attention.self.value.weight', 'encoder.layer.0.attention.output.LayerNorm.weight', 'encoder.layer.3.attention.output.LayerNorm.bias', 'encoder.layer.7.intermediate.dense.weight', 'encoder.layer.6.attention.self.query.bias', 'encoder.layer.9.attention.output.dense.bias', 'encoder.layer.8.attention.self.key.weight', 'encoder.layer.5.attention.output.dense.bias', 'encoder.layer.11.attention.output.dense.weight', 'encoder.layer.8.attention.self.query.weight', 'encoder.layer.10.output.dense.bias', 'encoder.layer.5.attention.self.value.bias', 'encoder.layer.3.attention.output.dense.bias', 'encoder.layer.11.intermediate.dense.weight', 'encoder.layer.10.attention.output.LayerNorm.weight', 'encoder.layer.2.intermediate.dense.bias', 'encoder.layer.0.attention.self.key.weight', 'encoder.layer.2.attention.self.key.bias', 'encoder.layer.2.attention.output.dense.weight', 'encoder.layer.11.attention.output.LayerNorm.weight', 'encoder.layer.7.attention.output.dense.weight', 'encoder.layer.3.attention.self.key.bias', 'encoder.layer.0.output.dense.bias', 'encoder.layer.11.attention.self.key.bias', 'encoder.layer.9.output.dense.bias', 'encoder.layer.0.attention.self.query.bias', 'encoder.layer.8.attention.output.dense.weight', 'encoder.layer.11.attention.output.dense.bias', 'encoder.layer.1.attention.self.value.bias', 'encoder.layer.4.output.dense.bias', 'encoder.layer.7.output.LayerNorm.weight', 'encoder.layer.7.attention.self.query.bias', 'encoder.layer.10.attention.output.dense.bias', 'encoder.layer.10.output.LayerNorm.weight', 'encoder.layer.9.attention.output.LayerNorm.weight', 'encoder.layer.3.intermediate.dense.bias', 'encoder.layer.1.outp ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,

# %%
def calcuate_accu(big_idx, targets):
    n_correct = (big_idx==targets).sum().item()
    return n_correct

# %%
import time
import datetime

def format_time(elapsed):
    #Takes a time in seconds and returns a string hh:mm:ss
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))   
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
from torch.utils.tensorboard import SummaryWriter

# default `log_dir` is "runs" - we'll be more specific here
writer = SummaryWriter('runs/Tensorboard')

# %%
# Start the training process:
import random
import torch

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
def train(epochs):
  total_t0 = time.time() # Measure the total training time for the whole run.
  tr_loss = 0
  n_correct = 0
  nb_tr_steps = 0
  nb_tr_examples = 0
  
  # For each epoch...
  for epoch in range(0, epochs):
      print('======== Epoch {:} / {:} ========'.format(epoch + 1, epochs))
      print('Training...')

      t0 = time.time()     # Measure how long the training epoch takes.
      total_tr_loss = 0
      total_n_correct = 0
      total_nb_tr_examples = 0
      model.train()    # Put the model into training mode

      # For each batch of training data...
      for step, batch in enumerate(train_dataloader, 0):     
          # 'batch' contains three pytorch tensors:[0]: input ids, [1]: attention masks, [2]: labels 
          input_ids = batch[0].to(device, dtype = torch.long)
          input_mask = batch[1].to(device, dtype = torch.long)
          labels = batch[2].to(device, dtype = torch.long)

          model.zero_grad()       #clear any previously calculated gradients 

          outputs = model(input_ids, token_type_ids=None, attention_mask=input_mask)
          loss_function = torch.nn.CrossEntropyLoss()
          loss = loss_function(outputs[0], labels) #`loss` is a Tensor containing a single value
          tr_loss += loss.item() #.item()` function just returns the Python value from the tensor
          total_tr_loss += loss.item()
          big_val, big_idx = torch.max(outputs[0], dim=1)
          n_correct += calcuate_accu(big_idx, labels)  
          total_n_correct += calcuate_accu(big_idx, labels)                  
          nb_tr_steps += 1
          nb_tr_examples+=labels.size(0)
          total_nb_tr_examples+=labels.size(0)

          if step % 20==19:
              loss_step = tr_loss/nb_tr_steps
              accu_step = n_correct/nb_tr_examples # #correct examples/all examples 
              print(f"Training Loss per 20 steps(batches): {loss_step}")
              print(f"Training Accuracy per 20 steps(batches): {accu_step}")
              elapsed = format_time(time.time() - t0)    # Calculate elapsed time in minutes.   
              # Report progress.
              print('Batch {} of {}.  Elapsed: {:}.'.format(step+1, len(train_dataloader), elapsed))
              #writer.add_scalar('training loss', loss_step, (epoch +1)*len(trainloader) )
              tr_loss = 0;n_correct = 0;nb_tr_steps = 0;nb_tr_examples = 0
                
          loss.backward() # Perform a backward pass to calculate the gradients.
          torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0) # Clip the norm of the gradients to 1.0. This is to help prevent the "exploding gradients" problem.
          optimizer.step()
          scheduler.step() # Update the learning rate.

    # Calculate the average loss over all of the batches.
      train_loss_per_epoch = total_tr_loss / len(train_dataloader)            
      train_accuracy_per_epoch=total_n_correct/total_nb_tr_examples
      # Measure how long this epoch took.
      training_time = format_time(time.time() - t0)

      print("")
      print("training loss per epoch: {0:.2f}".format(train_loss_per_epoch))
      print("training accuracy per epoch: {0:.2f}".format(train_accuracy_per_epoch))
      print("Training 1 epcoh took: {:}".format(training_time))

# %%
torch.cuda.memory_summary(device=None, abbreviated=False)
# Out:
# '|===========================================================================|\n|                  PyTorch CUDA memory summary, device ID 0                 |\n|---------------------------------------------------------------------------|\n|            CUDA OOMs: 0            |        cudaMalloc retries: 0         |\n|===========================================================================|\n|        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |\n|---------------------------------------------------------------------------|\n| Allocated memory      |  488244 KB |  488244 KB |  488244 KB |       0 B  |\n|       from large pool |  487680 KB |  487680 KB |  487680 KB |       0 B  |\n|       from small pool |     564 KB |     564 KB |     564 KB |       0 B  |\n|---------------------------------------------------------------------------|\n| Active memory         |  488244 KB |  488244 KB |  488244 KB |       0 B  |\n|       from large pool |  487680 KB |  487680 KB |  487680 KB |       0 B  |\n|       from small pool |     564 KB |     564 KB |     564 KB |       0 B  |\n|---------------------------------------------------------------------------|\n| GPU reserved memory   |  542720 KB |  542720 KB |  542720 KB |       0 B  |\n|       from large pool |  540672 KB |  540672 KB |  540672 KB |       0 B  |\n|       from small pool |    2048 KB |    2048 KB |    2048 KB |       0 B  |\n|---------------------------------------------------------------------------|\n| Non-releasable memory |   54475 KB |   54554 KB |  265207 KB |  210731 KB |\n|       from large pool |   52992 KB |   52992 KB |  263162 KB |  210170 KB |\n|       from small pool |    1483 KB |    2045 KB |    2045 KB |     561 KB |\n|---------------------------------------------------------------------------|\n| Allocations           |     203    |     203    |     203    |       0    |\n|       from large pool |      75    |      75    |      75    |       0    |\n|       from small pool |     128    |     128    |     128    |       0    |\n|---------------------------------------------------------------------------|\n| Active allocs         |     203    |     203    |     203    |       0    |\n|       from large pool |      75    |      75    |      75    |       0    |\n|       from small pool |     128    |     128    |     128    |       0    |\n|---------------------------------------------------------------------------|\n| GPU reserved segments |      21    |      21    |      21    |       0    |\n|       from large pool |      20    |      20    |      20    |       0    |\n|       from small pool |       1    |       1    |       1    |       0    |\n|---------------------------------------------------------------------------|\n| Non-releasable allocs |      19    |      19    |      20    |       1    |\n|       from large pool |      18    |      18    |      19    |       1    |\n|       from small pool |       1    |       1    |       1    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize allocations  |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize GPU segments |       0    |       0    |       0    |       0    |\n|===========================================================================|\n'

# %%
train(epochs = EPOCHS)
# Out:
# ======== Epoch 1 / 4 ========
# Training...
# Training Loss per 20 steps(batches): 2.035527801513672
# Training Accuracy per 20 steps(batches): 0.2875
# Batch 20 of 1866.  Elapsed: 0:00:28.
# Training Loss per 20 steps(batches): 1.5967637360095979
# Training Accuracy per 20 steps(batches): 0.35625
# Batch 40 of 1866.  Elapsed: 0:00:56.
# Training Loss per 20 steps(batches): 1.2981006860733033
# Training Accuracy per 20 steps(batches): 0.3875
# Batch 60 of 1866.  Elapsed: 0:01:24.
# Training Loss per 20 steps(batches): 1.0919921070337295
# Training Accuracy per 20 steps(batches): 0.48125
# Batch 80 of 1866.  Elapsed: 0:01:53.
# Training Loss per 20 steps(batches): 1.1009494185447692
# Training Accuracy per 20 steps(batches): 0.40625
# Batch 100 of 1866.  Elapsed: 0:02:21.
# Training Loss per 20 steps(batches): 0.9138560056686401
# Training Accuracy per 20 steps(batches): 0.56875
# Batch 120 of 1866.  Elapsed: 0:02:50.
# Training Loss per 20 steps(batches): 0.913647148013115
# Training Accuracy per 20 steps(batches): 0.53125
# Batch 140 of 1866.  Elapsed: 0:03:18.
# Training Loss per 20 steps(batches): 0.8343799367547036
# Training Accuracy per 20 steps(batches): 0.61875
# Batch 160 of 1866.  Elapsed: 0:03:47.
# Training Loss per 20 steps(batches): 0.7842826098203659
# Training Accuracy per 20 steps(batches): 0.675
# Batch 180 of 1866.  Elapsed: 0:04:15.
# Training Loss per 20 steps(batches): 0.7796419829130172
# Training Accuracy per 20 steps(batches): 0.63125
# Batch 200 of 1866.  Elapsed: 0:04:43.
# Training Loss per 20 steps(batches): 0.6810538426041604
# Training Accuracy per 20 steps(batches): 0.725
# Batch 220 of 1866.  Elapsed: 0:05:12.
# Training Loss per 20 steps(batches): 0.75068429261446
# Training Accuracy per 20 steps(batches): 0.74375
# Batch 240 of 1866.  Elapsed: 0:05:40.
# Training Loss per 20 steps(batches): 0.7638977196067571
# Training Accuracy per 20 steps(batches): 0.71875
# Batch 260 of 1866.  Elapsed: 0:06:09.
# Training Loss per 20 steps(batches): 0.6181730791926384
# Training Accuracy per 20 steps(batches): 0.70625
# Batch 280 of 1866.  Elapsed: 0:06:37.
# Training Loss per 20 steps(batches): 0.5962460473179817
# Training Accuracy per 20 steps(batches): 0.75625
# Batch 300 of 1866.  Elapsed: 0:07:05.
# Training Loss per 20 steps(batches): 0.5746978387236595
# Training Accuracy per 20 steps(batches): 0.79375
# Batch 320 of 1866.  Elapsed: 0:07:34.
# Training Loss per 20 steps(batches): 0.5693425580859184
# Training Accuracy per 20 steps(batches): 0.75625
# Batch 340 of 1866.  Elapsed: 0:08:02.
# Training Loss per 20 steps(batches): 0.5572239331901073
# Training Accuracy per 20 steps(batches): 0.79375
# Batch 360 of 1866.  Elapsed: 0:08:31.
# Training Loss per 20 steps(batches): 0.7354158446192741
# Training Accuracy per 20 steps(batches): 0.7125
# Batch 380 of 1866.  Elapsed: 0:08:59.
# Training Loss per 20 steps(batches): 0.515004375576973
# Training Accuracy per 20 steps(batches): 0.80625
# Batch 400 of 1866.  Elapsed: 0:09:27.
# Training Loss per 20 steps(batches): 0.5727917157113552
# Training Accuracy per 20 steps(batches): 0.74375
# Batch 420 of 1866.  Elapsed: 0:09:56.
# Training Loss per 20 steps(batches): 0.4244250044226646
# Training Accuracy per 20 steps(batches): 0.8625
# Batch 440 of 1866.  Elapsed: 0:10:24.
# Training Loss per 20 steps(batches): 0.5198109040036798
# Training Accuracy per 20 steps(batches): 0.80625
# Batch 460 of 1866.  Elapsed: 0:10:52.
# Training Loss per 20 steps(batches): 0.48608227260410786
# Training Accuracy per 20 steps(batches): 0.8125
# Batch 480 of 1866.  Elapsed: 0:11:21.
# Training Loss per 20 steps(batches): 0.7217035435140133
# Training Accuracy per 20 steps(batches): 0.7625
# Batch 500 of 1866.  Elapsed: 0:11:49.
# Training Loss per 20 steps(batches): 0.617130121588707
# Training Accuracy per 20 steps(batches): 0.76875
# Batch 520 of 1866.  Elapsed: 0:12:18.
# Training Loss per 20 steps(batches): 0.539519039541483
# Training Accuracy per 20 steps(batches): 0.8
# Batch 540 of 1866.  Elapsed: 0:12:46.
# Training Loss per 20 steps(batches): 0.5113770138472319
# Training Accuracy per 20 steps(batches): 0.81875
# Batch 560 of 1866.  Elapsed: 0:13:14.
# Training Loss per 20 steps(batches): 0.3916897792369127
# Training Accuracy per 20 steps(batches): 0.84375
# Batch 580 of 1866.  Elapsed: 0:13:43.
# Training Loss per 20 steps(batches): 0.5475703539326787
# Training Accuracy per 20 steps(batches): 0.8125
# Batch 600 of 1866.  Elapsed: 0:14:11.
# Training Loss per 20 steps(batches): 0.4446383384987712
# Training Accuracy per 20 steps(batches): 0.83125
# Batch 620 of 1866.  Elapsed: 0:14:40.
# Training Loss per 20 steps(batches): 0.49108655788004396
# Training Accuracy per 20 steps(batches): 0.83125
# Batch 640 of 1866.  Elapsed: 0:15:08.
# Training Loss per 20 steps(batches): 0.4293236590921879
# Training Accuracy per 20 steps(batches): 0.85625
# Batch 660 of 1866.  Elapsed: 0:15:36.
# Training Loss per 20 steps(batches): 0.36939946934580803
# Training Accuracy per 20 steps(batches): 0.8625
# Batch 680 of 1866.  Elapsed: 0:16:05.
# Training Loss per 20 steps(batches): 0.4756391080096364
# Training Accuracy per 20 steps(batches): 0.8375
# Batch 700 of 1866.  Elapsed: 0:16:33.
# Training Loss per 20 steps(batches): 0.4922945247963071
# Training Accuracy per 20 steps(batches): 0.825
# Batch 720 of 1866.  Elapsed: 0:17:01.
# Training Loss per 20 steps(batches): 0.5363470466807485
# Training Accuracy per 20 steps(batches): 0.83125
# Batch 740 of 1866.  Elapsed: 0:17:30.
# Training Loss per 20 steps(batches): 0.32661227993667125
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 760 of 1866.  Elapsed: 0:17:58.
# Training Loss per 20 steps(batches): 0.426973741594702
# Training Accuracy per 20 steps(batches): 0.83125
# Batch 780 of 1866.  Elapsed: 0:18:27.
# Training Loss per 20 steps(batches): 0.4940659638494253
# Training Accuracy per 20 steps(batches): 0.80625
# Batch 800 of 1866.  Elapsed: 0:18:55.
# Training Loss per 20 steps(batches): 0.5201913617551327
# Training Accuracy per 20 steps(batches): 0.79375
# Batch 820 of 1866.  Elapsed: 0:19:23.
# Training Loss per 20 steps(batches): 0.5178063526749611
# Training Accuracy per 20 steps(batches): 0.79375
# Batch 840 of 1866.  Elapsed: 0:19:52.
# Training Loss per 20 steps(batches): 0.5562385186553002
# Training Accuracy per 20 steps(batches): 0.81875
# Batch 860 of 1866.  Elapsed: 0:20:20.
# Training Loss per 20 steps(batches): 0.356122531183064
# Training Accuracy per 20 steps(batches): 0.8875
# Batch 880 of 1866.  Elapsed: 0:20:49.
# Training Loss per 20 steps(batches): 0.31353643918409946
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 900 of 1866.  Elapsed: 0:21:17.
# Training Loss per 20 steps(batches): 0.5560875166207552
# Training Accuracy per 20 steps(batches): 0.7875
# Batch 920 of 1866.  Elapsed: 0:21:45.
# Training Loss per 20 steps(batches): 0.4462772861123085
# Training Accuracy per 20 steps(batches): 0.825
# Batch 940 of 1866.  Elapsed: 0:22:14.
# Training Loss per 20 steps(batches): 0.49468494988977907
# Training Accuracy per 20 steps(batches): 0.85625
# Batch 960 of 1866.  Elapsed: 0:22:42.
# Training Loss per 20 steps(batches): 0.44583230298012494
# Training Accuracy per 20 steps(batches): 0.85
# Batch 980 of 1866.  Elapsed: 0:23:10.
# Training Loss per 20 steps(batches): 0.2826798938214779
# Training Accuracy per 20 steps(batches): 0.90625
# Batch 1000 of 1866.  Elapsed: 0:23:39.
# Training Loss per 20 steps(batches): 0.3983769878745079
# Training Accuracy per 20 steps(batches): 0.8875
# Batch 1020 of 1866.  Elapsed: 0:24:07.
# Training Loss per 20 steps(batches): 0.3801801213994622
# Training Accuracy per 20 steps(batches): 0.875
# Batch 1040 of 1866.  Elapsed: 0:24:36.
# Training Loss per 20 steps(batches): 0.4516233790665865
# Training Accuracy per 20 steps(batches): 0.81875
# Batch 1060 of 1866.  Elapsed: 0:25:04.
# Training Loss per 20 steps(batches): 0.3350371453911066
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 1080 of 1866.  Elapsed: 0:25:32.
# Training Loss per 20 steps(batches): 0.4579749809578061
# Training Accuracy per 20 steps(batches): 0.85625
# Batch 1100 of 1866.  Elapsed: 0:26:01.
# Training Loss per 20 steps(batches): 0.5535405202768743
# Training Accuracy per 20 steps(batches): 0.7875
# Batch 1120 of 1866.  Elapsed: 0:26:29.
# Training Loss per 20 steps(batches): 0.35490011889487505
# Training Accuracy per 20 steps(batches): 0.86875
# Batch 1140 of 1866.  Elapsed: 0:26:57.
# Training Loss per 20 steps(batches): 0.44402270317077636
# Training Accuracy per 20 steps(batches): 0.825
# Batch 1160 of 1866.  Elapsed: 0:27:26.
# Training Loss per 20 steps(batches): 0.442311030998826
# Training Accuracy per 20 steps(batches): 0.875
# Batch 1180 of 1866.  Elapsed: 0:27:54.
# Training Loss per 20 steps(batches): 0.5055222135037184
# Training Accuracy per 20 steps(batches): 0.83125
# Batch 1200 of 1866.  Elapsed: 0:28:22.
# Training Loss per 20 steps(batches): 0.41579288728535174
# Training Accuracy per 20 steps(batches): 0.84375
# Batch 1220 of 1866.  Elapsed: 0:28:51.
# Training Loss per 20 steps(batches): 0.4325456164777279
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 1240 of 1866.  Elapsed: 0:29:19.
# Training Loss per 20 steps(batches): 0.46664173621684313
# Training Accuracy per 20 steps(batches): 0.825
# Batch 1260 of 1866.  Elapsed: 0:29:47.
# Training Loss per 20 steps(batches): 0.4445251075550914
# Training Accuracy per 20 steps(batches): 0.84375
# Batch 1280 of 1866.  Elapsed: 0:30:16.
# Training Loss per 20 steps(batches): 0.4430647507309914
# Training Accuracy per 20 steps(batches): 0.8375
# Batch 1300 of 1866.  Elapsed: 0:30:44.
# Training Loss per 20 steps(batches): 0.42116527520120145
# Training Accuracy per 20 steps(batches): 0.80625
# Batch 1320 of 1866.  Elapsed: 0:31:12.
# Training Loss per 20 steps(batches): 0.38838006630539895
# Training Accuracy per 20 steps(batches): 0.85
# Batch 1340 of 1866.  Elapsed: 0:31:41.
# Training Loss per 20 steps(batches): 0.3633362567052245
# Training Accuracy per 20 steps(batches): 0.84375
# Batch 1360 of 1866.  Elapsed: 0:32:09.
# Training Loss per 20 steps(batches): 0.32860269071534276
# Training Accuracy per 20 steps(batches): 0.875
# Batch 1380 of 1866.  Elapsed: 0:32:38.
# Training Loss per 20 steps(batches): 0.47619954235851764
# Training Accuracy per 20 steps(batches): 0.85625
# Batch 1400 of 1866.  Elapsed: 0:33:06.
# Training Loss per 20 steps(batches): 0.31255041863769295
# Training Accuracy per 20 steps(batches): 0.86875
# Batch 1420 of 1866.  Elapsed: 0:33:34.
# Training Loss per 20 steps(batches): 0.5273995410650969
# Training Accuracy per 20 steps(batches): 0.83125
# Batch 1440 of 1866.  Elapsed: 0:34:03.
# Training Loss per 20 steps(batches): 0.35895190145820377
# Training Accuracy per 20 steps(batches): 0.875
# Batch 1460 of 1866.  Elapsed: 0:34:31.
# Training Loss per 20 steps(batches): 0.4234090505167842
# Training Accuracy per 20 steps(batches): 0.85625
# Batch 1480 of 1866.  Elapsed: 0:35:00.
# Training Loss per 20 steps(batches): 0.2932991713285446
# Training Accuracy per 20 steps(batches): 0.9
# Batch 1500 of 1866.  Elapsed: 0:35:28.
# Training Loss per 20 steps(batches): 0.41295184660702944
# Training Accuracy per 20 steps(batches): 0.86875
# Batch 1520 of 1866.  Elapsed: 0:35:56.
# Training Loss per 20 steps(batches): 0.341168674454093
# Training Accuracy per 20 steps(batches): 0.875
# Batch 1540 of 1866.  Elapsed: 0:36:25.
# Training Loss per 20 steps(batches): 0.19835296124219895
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 1560 of 1866.  Elapsed: 0:36:53.
# Training Loss per 20 steps(batches): 0.5180753362365067
# Training Accuracy per 20 steps(batches): 0.85
# Batch 1580 of 1866.  Elapsed: 0:37:22.
# Training Loss per 20 steps(batches): 0.47957574781030415
# Training Accuracy per 20 steps(batches): 0.86875
# Batch 1600 of 1866.  Elapsed: 0:37:50.
# Training Loss per 20 steps(batches): 0.4472497723996639
# Training Accuracy per 20 steps(batches): 0.85
# Batch 1620 of 1866.  Elapsed: 0:38:18.
# Training Loss per 20 steps(batches): 0.34276922382414343
# Training Accuracy per 20 steps(batches): 0.85625
# Batch 1640 of 1866.  Elapsed: 0:38:47.
# Training Loss per 20 steps(batches): 0.42301348187029364
# Training Accuracy per 20 steps(batches): 0.85625
# Batch 1660 of 1866.  Elapsed: 0:39:15.
# Training Loss per 20 steps(batches): 0.37625536471605303
# Training Accuracy per 20 steps(batches): 0.875
# Batch 1680 of 1866.  Elapsed: 0:39:43.
# Training Loss per 20 steps(batches): 0.5328164753504098
# Training Accuracy per 20 steps(batches): 0.78125
# Batch 1700 of 1866.  Elapsed: 0:40:12.
# Training Loss per 20 steps(batches): 0.3492730610072613
# Training Accuracy per 20 steps(batches): 0.875
# Batch 1720 of 1866.  Elapsed: 0:40:40.
# Training Loss per 20 steps(batches): 0.40907473769038916
# Training Accuracy per 20 steps(batches): 0.85625
# Batch 1740 of 1866.  Elapsed: 0:41:09.
# Training Loss per 20 steps(batches): 0.31076425686478615
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 1760 of 1866.  Elapsed: 0:41:37.
# Training Loss per 20 steps(batches): 0.35735545167699456
# Training Accuracy per 20 steps(batches): 0.86875
# Batch 1780 of 1866.  Elapsed: 0:42:05.
# Training Loss per 20 steps(batches): 0.4311438898090273
# Training Accuracy per 20 steps(batches): 0.85625
# Batch 1800 of 1866.  Elapsed: 0:42:34.
# Training Loss per 20 steps(batches): 0.43580298041924836
# Training Accuracy per 20 steps(batches): 0.84375
# Batch 1820 of 1866.  Elapsed: 0:43:02.
# Training Loss per 20 steps(batches): 0.7210081269033253
# Training Accuracy per 20 steps(batches): 0.80625
# Batch 1840 of 1866.  Elapsed: 0:43:30.
# Training Loss per 20 steps(batches): 0.40607739649713037
# Training Accuracy per 20 steps(batches): 0.84375
# Batch 1860 of 1866.  Elapsed: 0:43:59.
#
# training loss per epoch: 0.54
# training accuracy per epoch: 0.80
# Training 1 epcoh took: 0:44:07
# ======== Epoch 2 / 4 ========
# Training...
# Training Loss per 20 steps(batches): 0.4507640153169632
# Training Accuracy per 20 steps(batches): 0.8472906403940886
# Batch 20 of 1866.  Elapsed: 0:00:28.
# Training Loss per 20 steps(batches): 0.3117910731583834
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 40 of 1866.  Elapsed: 0:00:56.
# Training Loss per 20 steps(batches): 0.4490259985439479
# Training Accuracy per 20 steps(batches): 0.85
# Batch 60 of 1866.  Elapsed: 0:01:24.
# Training Loss per 20 steps(batches): 0.31295832509640603
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 80 of 1866.  Elapsed: 0:01:53.
# Training Loss per 20 steps(batches): 0.4260956967249513
# Training Accuracy per 20 steps(batches): 0.84375
# Batch 100 of 1866.  Elapsed: 0:02:21.
# Training Loss per 20 steps(batches): 0.31708921156823633
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 120 of 1866.  Elapsed: 0:02:49.
# Training Loss per 20 steps(batches): 0.432472751615569
# Training Accuracy per 20 steps(batches): 0.85625
# Batch 140 of 1866.  Elapsed: 0:03:18.
# Training Loss per 20 steps(batches): 0.37045990033075216
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 160 of 1866.  Elapsed: 0:03:46.
# Training Loss per 20 steps(batches): 0.39190721288323405
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 180 of 1866.  Elapsed: 0:04:15.
# Training Loss per 20 steps(batches): 0.4386742809787393
# Training Accuracy per 20 steps(batches): 0.875
# Batch 200 of 1866.  Elapsed: 0:04:43.
# Training Loss per 20 steps(batches): 0.4086472099646926
# Training Accuracy per 20 steps(batches): 0.86875
# Batch 220 of 1866.  Elapsed: 0:05:11.
# Training Loss per 20 steps(batches): 0.4983694372698665
# Training Accuracy per 20 steps(batches): 0.83125
# Batch 240 of 1866.  Elapsed: 0:05:40.
# Training Loss per 20 steps(batches): 0.2680421219207346
# Training Accuracy per 20 steps(batches): 0.9
# Batch 260 of 1866.  Elapsed: 0:06:08.
# Training Loss per 20 steps(batches): 0.2871897450648248
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 280 of 1866.  Elapsed: 0:06:36.
# Training Loss per 20 steps(batches): 0.3449011085787788
# Training Accuracy per 20 steps(batches): 0.875
# Batch 300 of 1866.  Elapsed: 0:07:05.
# Training Loss per 20 steps(batches): 0.3758516617584974
# Training Accuracy per 20 steps(batches): 0.875
# Batch 320 of 1866.  Elapsed: 0:07:33.
# Training Loss per 20 steps(batches): 0.34667749172076584
# Training Accuracy per 20 steps(batches): 0.90625
# Batch 340 of 1866.  Elapsed: 0:08:02.
# Training Loss per 20 steps(batches): 0.22214645515196024
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 360 of 1866.  Elapsed: 0:08:30.
# Training Loss per 20 steps(batches): 0.2142462581396103
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 380 of 1866.  Elapsed: 0:08:58.
# Training Loss per 20 steps(batches): 0.5067263061180711
# Training Accuracy per 20 steps(batches): 0.86875
# Batch 400 of 1866.  Elapsed: 0:09:27.
# Training Loss per 20 steps(batches): 0.260015040403232
# Training Accuracy per 20 steps(batches): 0.9125
# Batch 420 of 1866.  Elapsed: 0:09:55.
# Training Loss per 20 steps(batches): 0.2291759136132896
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 440 of 1866.  Elapsed: 0:10:24.
# Training Loss per 20 steps(batches): 0.4371054712217301
# Training Accuracy per 20 steps(batches): 0.8625
# Batch 460 of 1866.  Elapsed: 0:10:52.
# Training Loss per 20 steps(batches): 0.2810766818234697
# Training Accuracy per 20 steps(batches): 0.9
# Batch 480 of 1866.  Elapsed: 0:11:20.
# Training Loss per 20 steps(batches): 0.33838885873556135
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 500 of 1866.  Elapsed: 0:11:49.
# Training Loss per 20 steps(batches): 0.3177181657869369
# Training Accuracy per 20 steps(batches): 0.8875
# Batch 520 of 1866.  Elapsed: 0:12:17.
# Training Loss per 20 steps(batches): 0.20076878927648067
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 540 of 1866.  Elapsed: 0:12:45.
# Training Loss per 20 steps(batches): 0.43709106161259115
# Training Accuracy per 20 steps(batches): 0.8625
# Batch 560 of 1866.  Elapsed: 0:13:14.
# Training Loss per 20 steps(batches): 0.45681197149679065
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 580 of 1866.  Elapsed: 0:13:42.
# Training Loss per 20 steps(batches): 0.3652875791536644
# Training Accuracy per 20 steps(batches): 0.8625
# Batch 600 of 1866.  Elapsed: 0:14:10.
# Training Loss per 20 steps(batches): 0.36647074967622756
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 620 of 1866.  Elapsed: 0:14:39.
# Training Loss per 20 steps(batches): 0.44203059040009973
# Training Accuracy per 20 steps(batches): 0.8625
# Batch 640 of 1866.  Elapsed: 0:15:07.
# Training Loss per 20 steps(batches): 0.219403868727386
# Training Accuracy per 20 steps(batches): 0.925
# Batch 660 of 1866.  Elapsed: 0:15:36.
# Training Loss per 20 steps(batches): 0.15644262111745774
# Training Accuracy per 20 steps(batches): 0.95
# Batch 680 of 1866.  Elapsed: 0:16:04.
# Training Loss per 20 steps(batches): 0.36152090090326966
# Training Accuracy per 20 steps(batches): 0.8875
# Batch 700 of 1866.  Elapsed: 0:16:32.
# Training Loss per 20 steps(batches): 0.3255162530578673
# Training Accuracy per 20 steps(batches): 0.8875
# Batch 720 of 1866.  Elapsed: 0:17:01.
# Training Loss per 20 steps(batches): 0.4866066954098642
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 740 of 1866.  Elapsed: 0:17:29.
# Training Loss per 20 steps(batches): 0.1727800398133695
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 760 of 1866.  Elapsed: 0:17:58.
# Training Loss per 20 steps(batches): 0.32783393263816835
# Training Accuracy per 20 steps(batches): 0.8875
# Batch 780 of 1866.  Elapsed: 0:18:26.
# Training Loss per 20 steps(batches): 0.3839634694857523
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 800 of 1866.  Elapsed: 0:18:54.
# Training Loss per 20 steps(batches): 0.4478648607851937
# Training Accuracy per 20 steps(batches): 0.875
# Batch 820 of 1866.  Elapsed: 0:19:23.
# Training Loss per 20 steps(batches): 0.4041188777424395
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 840 of 1866.  Elapsed: 0:19:51.
# Training Loss per 20 steps(batches): 0.3859951270045713
# Training Accuracy per 20 steps(batches): 0.90625
# Batch 860 of 1866.  Elapsed: 0:20:20.
# Training Loss per 20 steps(batches): 0.30197569015435877
# Training Accuracy per 20 steps(batches): 0.8875
# Batch 880 of 1866.  Elapsed: 0:20:48.
# Training Loss per 20 steps(batches): 0.34897979721426964
# Training Accuracy per 20 steps(batches): 0.90625
# Batch 900 of 1866.  Elapsed: 0:21:16.
# Training Loss per 20 steps(batches): 0.3889816981041804
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 920 of 1866.  Elapsed: 0:21:45.
# Training Loss per 20 steps(batches): 0.40100677045993505
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 940 of 1866.  Elapsed: 0:22:13.
# Training Loss per 20 steps(batches): 0.4248940874123946
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 960 of 1866.  Elapsed: 0:22:42.
# Training Loss per 20 steps(batches): 0.2969410756602883
# Training Accuracy per 20 steps(batches): 0.9125
# Batch 980 of 1866.  Elapsed: 0:23:10.
# Training Loss per 20 steps(batches): 0.382156477868557
# Training Accuracy per 20 steps(batches): 0.8625
# Batch 1000 of 1866.  Elapsed: 0:23:38.
# Training Loss per 20 steps(batches): 0.25830140155740083
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 1020 of 1866.  Elapsed: 0:24:07.
# Training Loss per 20 steps(batches): 0.3361356545239687
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 1040 of 1866.  Elapsed: 0:24:35.
# Training Loss per 20 steps(batches): 0.3797075714217499
# Training Accuracy per 20 steps(batches): 0.86875
# Batch 1060 of 1866.  Elapsed: 0:25:04.
# Training Loss per 20 steps(batches): 0.4903075342066586
# Training Accuracy per 20 steps(batches): 0.86875
# Batch 1080 of 1866.  Elapsed: 0:25:32.
# Training Loss per 20 steps(batches): 0.34540740489028393
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 1100 of 1866.  Elapsed: 0:26:01.
# Training Loss per 20 steps(batches): 0.3977560481522232
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 1120 of 1866.  Elapsed: 0:26:29.
# Training Loss per 20 steps(batches): 0.31627316556405277
# Training Accuracy per 20 steps(batches): 0.90625
# Batch 1140 of 1866.  Elapsed: 0:26:57.
# Training Loss per 20 steps(batches): 0.2424795432481915
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 1160 of 1866.  Elapsed: 0:27:26.
# Training Loss per 20 steps(batches): 0.32128553949296473
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 1180 of 1866.  Elapsed: 0:27:54.
# Training Loss per 20 steps(batches): 0.35564655759371816
# Training Accuracy per 20 steps(batches): 0.9125
# Batch 1200 of 1866.  Elapsed: 0:28:23.
# Training Loss per 20 steps(batches): 0.19077431804034858
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 1220 of 1866.  Elapsed: 0:28:51.
# Training Loss per 20 steps(batches): 0.4646704878541641
# Training Accuracy per 20 steps(batches): 0.86875
# Batch 1240 of 1866.  Elapsed: 0:29:19.
# Training Loss per 20 steps(batches): 0.3189968305174261
# Training Accuracy per 20 steps(batches): 0.9
# Batch 1260 of 1866.  Elapsed: 0:29:48.
# Training Loss per 20 steps(batches): 0.2704476417042315
# Training Accuracy per 20 steps(batches): 0.9
# Batch 1280 of 1866.  Elapsed: 0:30:16.
# Training Loss per 20 steps(batches): 0.206920200958848
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 1300 of 1866.  Elapsed: 0:30:45.
# Training Loss per 20 steps(batches): 0.38983535482548176
# Training Accuracy per 20 steps(batches): 0.9
# Batch 1320 of 1866.  Elapsed: 0:31:13.
# Training Loss per 20 steps(batches): 0.4078752723522484
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 1340 of 1866.  Elapsed: 0:31:41.
# Training Loss per 20 steps(batches): 0.248143226839602
# Training Accuracy per 20 steps(batches): 0.925
# Batch 1360 of 1866.  Elapsed: 0:32:10.
# Training Loss per 20 steps(batches): 0.2714619035832584
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 1380 of 1866.  Elapsed: 0:32:38.
# Training Loss per 20 steps(batches): 0.39110385614912957
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 1400 of 1866.  Elapsed: 0:33:07.
# Training Loss per 20 steps(batches): 0.20841657929122448
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 1420 of 1866.  Elapsed: 0:33:35.
# Training Loss per 20 steps(batches): 0.3629410196328536
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 1440 of 1866.  Elapsed: 0:34:03.
# Training Loss per 20 steps(batches): 0.49583057705312966
# Training Accuracy per 20 steps(batches): 0.8625
# Batch 1460 of 1866.  Elapsed: 0:34:32.
# Training Loss per 20 steps(batches): 0.23978967079892755
# Training Accuracy per 20 steps(batches): 0.9
# Batch 1480 of 1866.  Elapsed: 0:35:00.
# Training Loss per 20 steps(batches): 0.2788797940593213
# Training Accuracy per 20 steps(batches): 0.925
# Batch 1500 of 1866.  Elapsed: 0:35:29.
# Training Loss per 20 steps(batches): 0.3755437593907118
# Training Accuracy per 20 steps(batches): 0.8875
# Batch 1520 of 1866.  Elapsed: 0:35:57.
# Training Loss per 20 steps(batches): 0.33150887745432556
# Training Accuracy per 20 steps(batches): 0.9
# Batch 1540 of 1866.  Elapsed: 0:36:25.
# Training Loss per 20 steps(batches): 0.38236657353118064
# Training Accuracy per 20 steps(batches): 0.8875
# Batch 1560 of 1866.  Elapsed: 0:36:54.
# Training Loss per 20 steps(batches): 0.3381336613558233
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 1580 of 1866.  Elapsed: 0:37:22.
# Training Loss per 20 steps(batches): 0.2534863967448473
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 1600 of 1866.  Elapsed: 0:37:51.
# Training Loss per 20 steps(batches): 0.25269718253985046
# Training Accuracy per 20 steps(batches): 0.90625
# Batch 1620 of 1866.  Elapsed: 0:38:19.
# Training Loss per 20 steps(batches): 0.3823919242247939
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 1640 of 1866.  Elapsed: 0:38:48.
# Training Loss per 20 steps(batches): 0.35937152155674995
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 1660 of 1866.  Elapsed: 0:39:16.
# Training Loss per 20 steps(batches): 0.36434130056295544
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 1680 of 1866.  Elapsed: 0:39:44.
# Training Loss per 20 steps(batches): 0.27147471592761574
# Training Accuracy per 20 steps(batches): 0.9125
# Batch 1700 of 1866.  Elapsed: 0:40:13.
# Training Loss per 20 steps(batches): 0.31490077381022274
# Training Accuracy per 20 steps(batches): 0.9
# Batch 1720 of 1866.  Elapsed: 0:40:41.
# Training Loss per 20 steps(batches): 0.31999950474128125
# Training Accuracy per 20 steps(batches): 0.9
# Batch 1740 of 1866.  Elapsed: 0:41:10.
# Training Loss per 20 steps(batches): 0.29177545704878866
# Training Accuracy per 20 steps(batches): 0.9125
# Batch 1760 of 1866.  Elapsed: 0:41:38.
# Training Loss per 20 steps(batches): 0.2550844025798142
# Training Accuracy per 20 steps(batches): 0.925
# Batch 1780 of 1866.  Elapsed: 0:42:06.
# Training Loss per 20 steps(batches): 0.43455268405377867
# Training Accuracy per 20 steps(batches): 0.9
# Batch 1800 of 1866.  Elapsed: 0:42:35.
# Training Loss per 20 steps(batches): 0.5036596938036382
# Training Accuracy per 20 steps(batches): 0.8375
# Batch 1820 of 1866.  Elapsed: 0:43:03.
# Training Loss per 20 steps(batches): 0.24394487193785608
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 1840 of 1866.  Elapsed: 0:43:32.
# Training Loss per 20 steps(batches): 0.44911711327731607
# Training Accuracy per 20 steps(batches): 0.84375
# Batch 1860 of 1866.  Elapsed: 0:44:00.
#
# training loss per epoch: 0.34
# training accuracy per epoch: 0.89
# Training 1 epcoh took: 0:44:09
# ======== Epoch 3 / 4 ========
# Training...
# Training Loss per 20 steps(batches): 0.2189443884238314
# Training Accuracy per 20 steps(batches): 0.9359605911330049
# Batch 20 of 1866.  Elapsed: 0:00:28.
# Training Loss per 20 steps(batches): 0.1119055628310889
# Training Accuracy per 20 steps(batches): 0.96875
# Batch 40 of 1866.  Elapsed: 0:00:56.
# Training Loss per 20 steps(batches): 0.23421043426496907
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 60 of 1866.  Elapsed: 0:01:24.
# Training Loss per 20 steps(batches): 0.46766733427066354
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 80 of 1866.  Elapsed: 0:01:53.
# Training Loss per 20 steps(batches): 0.19757465163711457
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 100 of 1866.  Elapsed: 0:02:21.
# Training Loss per 20 steps(batches): 0.3716340586310253
# Training Accuracy per 20 steps(batches): 0.90625
# Batch 120 of 1866.  Elapsed: 0:02:49.
# Training Loss per 20 steps(batches): 0.27993130264803767
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 140 of 1866.  Elapsed: 0:03:18.
# Training Loss per 20 steps(batches): 0.22314994363114238
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 160 of 1866.  Elapsed: 0:03:46.
# Training Loss per 20 steps(batches): 0.24814958549104632
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 180 of 1866.  Elapsed: 0:04:15.
# Training Loss per 20 steps(batches): 0.22402976816520095
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 200 of 1866.  Elapsed: 0:04:43.
# Training Loss per 20 steps(batches): 0.21526142661459743
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 220 of 1866.  Elapsed: 0:05:11.
# Training Loss per 20 steps(batches): 0.1907493900042027
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 240 of 1866.  Elapsed: 0:05:40.
# Training Loss per 20 steps(batches): 0.26447534185135735
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 260 of 1866.  Elapsed: 0:06:08.
# Training Loss per 20 steps(batches): 0.2862001414876431
# Training Accuracy per 20 steps(batches): 0.9
# Batch 280 of 1866.  Elapsed: 0:06:37.
# Training Loss per 20 steps(batches): 0.26406194088049234
# Training Accuracy per 20 steps(batches): 0.9125
# Batch 300 of 1866.  Elapsed: 0:07:05.
# Training Loss per 20 steps(batches): 0.13845722037367522
# Training Accuracy per 20 steps(batches): 0.9625
# Batch 320 of 1866.  Elapsed: 0:07:34.
# Training Loss per 20 steps(batches): 0.3672376342350617
# Training Accuracy per 20 steps(batches): 0.90625
# Batch 340 of 1866.  Elapsed: 0:08:02.
# Training Loss per 20 steps(batches): 0.28126899723429233
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 360 of 1866.  Elapsed: 0:08:30.
# Training Loss per 20 steps(batches): 0.2526609500637278
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 380 of 1866.  Elapsed: 0:08:59.
# Training Loss per 20 steps(batches): 0.2598949728999287
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 400 of 1866.  Elapsed: 0:09:27.
# Training Loss per 20 steps(batches): 0.25315531746018677
# Training Accuracy per 20 steps(batches): 0.9125
# Batch 420 of 1866.  Elapsed: 0:09:56.
# Training Loss per 20 steps(batches): 0.23063013269566
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 440 of 1866.  Elapsed: 0:10:24.
# Training Loss per 20 steps(batches): 0.34661562615074215
# Training Accuracy per 20 steps(batches): 0.8875
# Batch 460 of 1866.  Elapsed: 0:10:53.
# Training Loss per 20 steps(batches): 0.33649105865042656
# Training Accuracy per 20 steps(batches): 0.875
# Batch 480 of 1866.  Elapsed: 0:11:21.
# Training Loss per 20 steps(batches): 0.3193389970809221
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 500 of 1866.  Elapsed: 0:11:50.
# Training Loss per 20 steps(batches): 0.25845280084759
# Training Accuracy per 20 steps(batches): 0.90625
# Batch 520 of 1866.  Elapsed: 0:12:18.
# Training Loss per 20 steps(batches): 0.1326083300751634
# Training Accuracy per 20 steps(batches): 0.95625
# Batch 540 of 1866.  Elapsed: 0:12:46.
# Training Loss per 20 steps(batches): 0.35184224441181866
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 560 of 1866.  Elapsed: 0:13:15.
# Training Loss per 20 steps(batches): 0.3648437211755663
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 580 of 1866.  Elapsed: 0:13:43.
# Training Loss per 20 steps(batches): 0.23853442828403787
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 600 of 1866.  Elapsed: 0:14:12.
# Training Loss per 20 steps(batches): 0.21224594712257386
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 620 of 1866.  Elapsed: 0:14:40.
# Training Loss per 20 steps(batches): 0.13906625534873457
# Training Accuracy per 20 steps(batches): 0.95625
# Batch 640 of 1866.  Elapsed: 0:15:09.
# Training Loss per 20 steps(batches): 0.38224374372512104
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 660 of 1866.  Elapsed: 0:15:37.
# Training Loss per 20 steps(batches): 0.25991743786726146
# Training Accuracy per 20 steps(batches): 0.9125
# Batch 680 of 1866.  Elapsed: 0:16:05.
# Training Loss per 20 steps(batches): 0.1533044971874915
# Training Accuracy per 20 steps(batches): 0.95625
# Batch 700 of 1866.  Elapsed: 0:16:34.
# Training Loss per 20 steps(batches): 0.412583478121087
# Training Accuracy per 20 steps(batches): 0.9
# Batch 720 of 1866.  Elapsed: 0:17:02.
# Training Loss per 20 steps(batches): 0.3161225346149877
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 740 of 1866.  Elapsed: 0:17:31.
# Training Loss per 20 steps(batches): 0.24240227974951267
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 760 of 1866.  Elapsed: 0:17:59.
# Training Loss per 20 steps(batches): 0.20536811940837651
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 780 of 1866.  Elapsed: 0:18:27.
# Training Loss per 20 steps(batches): 0.3065352384117432
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 800 of 1866.  Elapsed: 0:18:56.
# Training Loss per 20 steps(batches): 0.38048782030818984
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 820 of 1866.  Elapsed: 0:19:24.
# Training Loss per 20 steps(batches): 0.27425527207087724
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 840 of 1866.  Elapsed: 0:19:53.
# Training Loss per 20 steps(batches): 0.4670947039034218
# Training Accuracy per 20 steps(batches): 0.85
# Batch 860 of 1866.  Elapsed: 0:20:21.
# Training Loss per 20 steps(batches): 0.4579906838247553
# Training Accuracy per 20 steps(batches): 0.875
# Batch 880 of 1866.  Elapsed: 0:20:49.
# Training Loss per 20 steps(batches): 0.30678390748798845
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 900 of 1866.  Elapsed: 0:21:18.
# Training Loss per 20 steps(batches): 0.4519748302642256
# Training Accuracy per 20 steps(batches): 0.875
# Batch 920 of 1866.  Elapsed: 0:21:46.
# Training Loss per 20 steps(batches): 0.224604132771492
# Training Accuracy per 20 steps(batches): 0.925
# Batch 940 of 1866.  Elapsed: 0:22:15.
# Training Loss per 20 steps(batches): 0.34833028219873086
# Training Accuracy per 20 steps(batches): 0.86875
# Batch 960 of 1866.  Elapsed: 0:22:43.
# Training Loss per 20 steps(batches): 0.21946246300358324
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 980 of 1866.  Elapsed: 0:23:12.
# Training Loss per 20 steps(batches): 0.3193507026997395
# Training Accuracy per 20 steps(batches): 0.9125
# Batch 1000 of 1866.  Elapsed: 0:23:40.
# Training Loss per 20 steps(batches): 0.3151899271528237
# Training Accuracy per 20 steps(batches): 0.90625
# Batch 1020 of 1866.  Elapsed: 0:24:08.
# Training Loss per 20 steps(batches): 0.24652304745977743
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1040 of 1866.  Elapsed: 0:24:37.
# Training Loss per 20 steps(batches): 0.27410545719321816
# Training Accuracy per 20 steps(batches): 0.925
# Batch 1060 of 1866.  Elapsed: 0:25:05.
# Training Loss per 20 steps(batches): 0.31266203629784284
# Training Accuracy per 20 steps(batches): 0.9125
# Batch 1080 of 1866.  Elapsed: 0:25:33.
# Training Loss per 20 steps(batches): 0.3640713752247393
# Training Accuracy per 20 steps(batches): 0.9
# Batch 1100 of 1866.  Elapsed: 0:26:02.
# Training Loss per 20 steps(batches): 0.20288620670326055
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1120 of 1866.  Elapsed: 0:26:30.
# Training Loss per 20 steps(batches): 0.297268381039612
# Training Accuracy per 20 steps(batches): 0.88125
# Batch 1140 of 1866.  Elapsed: 0:26:59.
# Training Loss per 20 steps(batches): 0.15548293004976585
# Training Accuracy per 20 steps(batches): 0.95
# Batch 1160 of 1866.  Elapsed: 0:27:27.
# Training Loss per 20 steps(batches): 0.21130914544919505
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1180 of 1866.  Elapsed: 0:27:55.
# Training Loss per 20 steps(batches): 0.4107608920428902
# Training Accuracy per 20 steps(batches): 0.875
# Batch 1200 of 1866.  Elapsed: 0:28:24.
# Training Loss per 20 steps(batches): 0.15786851820303127
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 1220 of 1866.  Elapsed: 0:28:52.
# Training Loss per 20 steps(batches): 0.23447869308292865
# Training Accuracy per 20 steps(batches): 0.9125
# Batch 1240 of 1866.  Elapsed: 0:29:21.
# Training Loss per 20 steps(batches): 0.27366630602627995
# Training Accuracy per 20 steps(batches): 0.925
# Batch 1260 of 1866.  Elapsed: 0:29:49.
# Training Loss per 20 steps(batches): 0.2919245791970752
# Training Accuracy per 20 steps(batches): 0.90625
# Batch 1280 of 1866.  Elapsed: 0:30:17.
# Training Loss per 20 steps(batches): 0.2182641708292067
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 1300 of 1866.  Elapsed: 0:30:46.
# Training Loss per 20 steps(batches): 0.2351853070082143
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 1320 of 1866.  Elapsed: 0:31:14.
# Training Loss per 20 steps(batches): 0.28450906469952314
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 1340 of 1866.  Elapsed: 0:31:43.
# Training Loss per 20 steps(batches): 0.32239688142435624
# Training Accuracy per 20 steps(batches): 0.9125
# Batch 1360 of 1866.  Elapsed: 0:32:11.
# Training Loss per 20 steps(batches): 0.14523595003411174
# Training Accuracy per 20 steps(batches): 0.95
# Batch 1380 of 1866.  Elapsed: 0:32:39.
# Training Loss per 20 steps(batches): 0.22529524749843405
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1400 of 1866.  Elapsed: 0:33:07.
# Training Loss per 20 steps(batches): 0.3261021085898392
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 1420 of 1866.  Elapsed: 0:33:36.
# Training Loss per 20 steps(batches): 0.25461126359878106
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1440 of 1866.  Elapsed: 0:34:04.
# Training Loss per 20 steps(batches): 0.3430310028605163
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 1460 of 1866.  Elapsed: 0:34:32.
# Training Loss per 20 steps(batches): 0.290622411086224
# Training Accuracy per 20 steps(batches): 0.9
# Batch 1480 of 1866.  Elapsed: 0:35:01.
# Training Loss per 20 steps(batches): 0.17890823546331375
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1500 of 1866.  Elapsed: 0:35:29.
# Training Loss per 20 steps(batches): 0.27038694457150997
# Training Accuracy per 20 steps(batches): 0.925
# Batch 1520 of 1866.  Elapsed: 0:35:58.
# Training Loss per 20 steps(batches): 0.27283751574577764
# Training Accuracy per 20 steps(batches): 0.925
# Batch 1540 of 1866.  Elapsed: 0:36:26.
# Training Loss per 20 steps(batches): 0.16887189695844426
# Training Accuracy per 20 steps(batches): 0.95
# Batch 1560 of 1866.  Elapsed: 0:36:54.
# Training Loss per 20 steps(batches): 0.17615731563419104
# Training Accuracy per 20 steps(batches): 0.9625
# Batch 1580 of 1866.  Elapsed: 0:37:23.
# Training Loss per 20 steps(batches): 0.33482849382562563
# Training Accuracy per 20 steps(batches): 0.9
# Batch 1600 of 1866.  Elapsed: 0:37:51.
# Training Loss per 20 steps(batches): 0.2409466757089831
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 1620 of 1866.  Elapsed: 0:38:20.
# Training Loss per 20 steps(batches): 0.28297274161595853
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 1640 of 1866.  Elapsed: 0:38:48.
# Training Loss per 20 steps(batches): 0.21930382002610713
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 1660 of 1866.  Elapsed: 0:39:16.
# Training Loss per 20 steps(batches): 0.16188400331884623
# Training Accuracy per 20 steps(batches): 0.95
# Batch 1680 of 1866.  Elapsed: 0:39:45.
# Training Loss per 20 steps(batches): 0.3061264687683433
# Training Accuracy per 20 steps(batches): 0.9
# Batch 1700 of 1866.  Elapsed: 0:40:13.
# Training Loss per 20 steps(batches): 0.12426702892989852
# Training Accuracy per 20 steps(batches): 0.95625
# Batch 1720 of 1866.  Elapsed: 0:40:42.
# Training Loss per 20 steps(batches): 0.3138022655621171
# Training Accuracy per 20 steps(batches): 0.9125
# Batch 1740 of 1866.  Elapsed: 0:41:10.
# Training Loss per 20 steps(batches): 0.2328342542867176
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 1760 of 1866.  Elapsed: 0:41:38.
# Training Loss per 20 steps(batches): 0.21336967669194565
# Training Accuracy per 20 steps(batches): 0.95
# Batch 1780 of 1866.  Elapsed: 0:42:07.
# Training Loss per 20 steps(batches): 0.44827460527885704
# Training Accuracy per 20 steps(batches): 0.89375
# Batch 1800 of 1866.  Elapsed: 0:42:35.
# Training Loss per 20 steps(batches): 0.2148718918208033
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 1820 of 1866.  Elapsed: 0:43:04.
# Training Loss per 20 steps(batches): 0.1825016644783318
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1840 of 1866.  Elapsed: 0:43:32.
# Training Loss per 20 steps(batches): 0.2614876552252099
# Training Accuracy per 20 steps(batches): 0.95
# Batch 1860 of 1866.  Elapsed: 0:44:00.
#
# training loss per epoch: 0.27
# training accuracy per epoch: 0.92
# Training 1 epcoh took: 0:44:09
# ======== Epoch 4 / 4 ========
# Training...
# Training Loss per 20 steps(batches): 0.06289959395787893
# Training Accuracy per 20 steps(batches): 0.9852216748768473
# Batch 20 of 1866.  Elapsed: 0:00:28.
# Training Loss per 20 steps(batches): 0.20832468236330898
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 40 of 1866.  Elapsed: 0:00:56.
# Training Loss per 20 steps(batches): 0.18374712569639087
# Training Accuracy per 20 steps(batches): 0.95625
# Batch 60 of 1866.  Elapsed: 0:01:24.
# Training Loss per 20 steps(batches): 0.12772500555729493
# Training Accuracy per 20 steps(batches): 0.95625
# Batch 80 of 1866.  Elapsed: 0:01:53.
# Training Loss per 20 steps(batches): 0.23758775127353146
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 100 of 1866.  Elapsed: 0:02:21.
# Training Loss per 20 steps(batches): 0.25673635461716915
# Training Accuracy per 20 steps(batches): 0.95
# Batch 120 of 1866.  Elapsed: 0:02:50.
# Training Loss per 20 steps(batches): 0.19545814649900423
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 140 of 1866.  Elapsed: 0:03:18.
# Training Loss per 20 steps(batches): 0.25973474921192974
# Training Accuracy per 20 steps(batches): 0.925
# Batch 160 of 1866.  Elapsed: 0:03:46.
# Training Loss per 20 steps(batches): 0.2404377099010162
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 180 of 1866.  Elapsed: 0:04:15.
# Training Loss per 20 steps(batches): 0.27920595366740597
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 200 of 1866.  Elapsed: 0:04:43.
# Training Loss per 20 steps(batches): 0.19037860342068597
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 220 of 1866.  Elapsed: 0:05:12.
# Training Loss per 20 steps(batches): 0.23967951892409473
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 240 of 1866.  Elapsed: 0:05:40.
# Training Loss per 20 steps(batches): 0.18387753263814374
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 260 of 1866.  Elapsed: 0:06:08.
# Training Loss per 20 steps(batches): 0.3575594019144773
# Training Accuracy per 20 steps(batches): 0.8875
# Batch 280 of 1866.  Elapsed: 0:06:37.
# Training Loss per 20 steps(batches): 0.18595975860371255
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 300 of 1866.  Elapsed: 0:07:05.
# Training Loss per 20 steps(batches): 0.27689983806340024
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 320 of 1866.  Elapsed: 0:07:33.
# Training Loss per 20 steps(batches): 0.23991934143705293
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 340 of 1866.  Elapsed: 0:08:02.
# Training Loss per 20 steps(batches): 0.22815073609817774
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 360 of 1866.  Elapsed: 0:08:30.
# Training Loss per 20 steps(batches): 0.16887553074629977
# Training Accuracy per 20 steps(batches): 0.95
# Batch 380 of 1866.  Elapsed: 0:08:59.
# Training Loss per 20 steps(batches): 0.22173835622379556
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 400 of 1866.  Elapsed: 0:09:27.
# Training Loss per 20 steps(batches): 0.3049793472280726
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 420 of 1866.  Elapsed: 0:09:55.
# Training Loss per 20 steps(batches): 0.134094891755376
# Training Accuracy per 20 steps(batches): 0.9625
# Batch 440 of 1866.  Elapsed: 0:10:24.
# Training Loss per 20 steps(batches): 0.22679488218855112
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 460 of 1866.  Elapsed: 0:10:52.
# Training Loss per 20 steps(batches): 0.207933875056915
# Training Accuracy per 20 steps(batches): 0.95
# Batch 480 of 1866.  Elapsed: 0:11:20.
# Training Loss per 20 steps(batches): 0.26399452131008727
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 500 of 1866.  Elapsed: 0:11:49.
# Training Loss per 20 steps(batches): 0.2469280812656507
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 520 of 1866.  Elapsed: 0:12:17.
# Training Loss per 20 steps(batches): 0.29934070743620395
# Training Accuracy per 20 steps(batches): 0.9125
# Batch 540 of 1866.  Elapsed: 0:12:45.
# Training Loss per 20 steps(batches): 0.13203824824886395
# Training Accuracy per 20 steps(batches): 0.96875
# Batch 560 of 1866.  Elapsed: 0:13:14.
# Training Loss per 20 steps(batches): 0.3189722380368039
# Training Accuracy per 20 steps(batches): 0.9125
# Batch 580 of 1866.  Elapsed: 0:13:42.
# Training Loss per 20 steps(batches): 0.2124469155445695
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 600 of 1866.  Elapsed: 0:14:11.
# Training Loss per 20 steps(batches): 0.306725517322775
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 620 of 1866.  Elapsed: 0:14:39.
# Training Loss per 20 steps(batches): 0.28774479308631273
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 640 of 1866.  Elapsed: 0:15:07.
# Training Loss per 20 steps(batches): 0.28814989810343833
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 660 of 1866.  Elapsed: 0:15:36.
# Training Loss per 20 steps(batches): 0.21059073376236484
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 680 of 1866.  Elapsed: 0:16:04.
# Training Loss per 20 steps(batches): 0.32823962306138127
# Training Accuracy per 20 steps(batches): 0.91875
# Batch 700 of 1866.  Elapsed: 0:16:32.
# Training Loss per 20 steps(batches): 0.20995302266674115
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 720 of 1866.  Elapsed: 0:17:01.
# Training Loss per 20 steps(batches): 0.2280618357937783
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 740 of 1866.  Elapsed: 0:17:29.
# Training Loss per 20 steps(batches): 0.08399528942536563
# Training Accuracy per 20 steps(batches): 0.975
# Batch 760 of 1866.  Elapsed: 0:17:58.
# Training Loss per 20 steps(batches): 0.21451240710448474
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 780 of 1866.  Elapsed: 0:18:26.
# Training Loss per 20 steps(batches): 0.17354171008337288
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 800 of 1866.  Elapsed: 0:18:54.
# Training Loss per 20 steps(batches): 0.24252098427386953
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 820 of 1866.  Elapsed: 0:19:23.
# Training Loss per 20 steps(batches): 0.36449033187236635
# Training Accuracy per 20 steps(batches): 0.9
# Batch 840 of 1866.  Elapsed: 0:19:51.
# Training Loss per 20 steps(batches): 0.25090998416999355
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 860 of 1866.  Elapsed: 0:20:19.
# Training Loss per 20 steps(batches): 0.15466707130544818
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 880 of 1866.  Elapsed: 0:20:48.
# Training Loss per 20 steps(batches): 0.20483249716926366
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 900 of 1866.  Elapsed: 0:21:16.
# Training Loss per 20 steps(batches): 0.17628999415319413
# Training Accuracy per 20 steps(batches): 0.95625
# Batch 920 of 1866.  Elapsed: 0:21:45.
# Training Loss per 20 steps(batches): 0.11157540290150791
# Training Accuracy per 20 steps(batches): 0.9625
# Batch 940 of 1866.  Elapsed: 0:22:13.
# Training Loss per 20 steps(batches): 0.2733092786744237
# Training Accuracy per 20 steps(batches): 0.925
# Batch 960 of 1866.  Elapsed: 0:22:41.
# Training Loss per 20 steps(batches): 0.27226793196750804
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 980 of 1866.  Elapsed: 0:23:10.
# Training Loss per 20 steps(batches): 0.2791743944399059
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 1000 of 1866.  Elapsed: 0:23:38.
# Training Loss per 20 steps(batches): 0.21707650125026703
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1020 of 1866.  Elapsed: 0:24:06.
# Training Loss per 20 steps(batches): 0.24613023556303232
# Training Accuracy per 20 steps(batches): 0.90625
# Batch 1040 of 1866.  Elapsed: 0:24:35.
# Training Loss per 20 steps(batches): 0.25411201008828355
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1060 of 1866.  Elapsed: 0:25:03.
# Training Loss per 20 steps(batches): 0.3579888711217791
# Training Accuracy per 20 steps(batches): 0.8875
# Batch 1080 of 1866.  Elapsed: 0:25:31.
# Training Loss per 20 steps(batches): 0.1881877374369651
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 1100 of 1866.  Elapsed: 0:26:00.
# Training Loss per 20 steps(batches): 0.18579600657103584
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 1120 of 1866.  Elapsed: 0:26:28.
# Training Loss per 20 steps(batches): 0.2186804646276869
# Training Accuracy per 20 steps(batches): 0.95
# Batch 1140 of 1866.  Elapsed: 0:26:57.
# Training Loss per 20 steps(batches): 0.23906060408917257
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 1160 of 1866.  Elapsed: 0:27:25.
# Training Loss per 20 steps(batches): 0.23870671591139397
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 1180 of 1866.  Elapsed: 0:27:53.
# Training Loss per 20 steps(batches): 0.3136716551263817
# Training Accuracy per 20 steps(batches): 0.90625
# Batch 1200 of 1866.  Elapsed: 0:28:22.
# Training Loss per 20 steps(batches): 0.22870973178651183
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1220 of 1866.  Elapsed: 0:28:50.
# Training Loss per 20 steps(batches): 0.09638058498967439
# Training Accuracy per 20 steps(batches): 0.96875
# Batch 1240 of 1866.  Elapsed: 0:29:18.
# Training Loss per 20 steps(batches): 0.1929347241704818
# Training Accuracy per 20 steps(batches): 0.96875
# Batch 1260 of 1866.  Elapsed: 0:29:47.
# Training Loss per 20 steps(batches): 0.17926692167529837
# Training Accuracy per 20 steps(batches): 0.95
# Batch 1280 of 1866.  Elapsed: 0:30:15.
# Training Loss per 20 steps(batches): 0.17826325063360854
# Training Accuracy per 20 steps(batches): 0.95
# Batch 1300 of 1866.  Elapsed: 0:30:44.
# Training Loss per 20 steps(batches): 0.15531504905084148
# Training Accuracy per 20 steps(batches): 0.95625
# Batch 1320 of 1866.  Elapsed: 0:31:12.
# Training Loss per 20 steps(batches): 0.1896222292096354
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1340 of 1866.  Elapsed: 0:31:40.
# Training Loss per 20 steps(batches): 0.17003106034826487
# Training Accuracy per 20 steps(batches): 0.9625
# Batch 1360 of 1866.  Elapsed: 0:32:09.
# Training Loss per 20 steps(batches): 0.13312159124179743
# Training Accuracy per 20 steps(batches): 0.9625
# Batch 1380 of 1866.  Elapsed: 0:32:37.
# Training Loss per 20 steps(batches): 0.32223815388279037
# Training Accuracy per 20 steps(batches): 0.925
# Batch 1400 of 1866.  Elapsed: 0:33:05.
# Training Loss per 20 steps(batches): 0.27422389030107297
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1420 of 1866.  Elapsed: 0:33:34.
# Training Loss per 20 steps(batches): 0.2712086655665189
# Training Accuracy per 20 steps(batches): 0.925
# Batch 1440 of 1866.  Elapsed: 0:34:02.
# Training Loss per 20 steps(batches): 0.21165049736155198
# Training Accuracy per 20 steps(batches): 0.95
# Batch 1460 of 1866.  Elapsed: 0:34:30.
# Training Loss per 20 steps(batches): 0.2175105283386074
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1480 of 1866.  Elapsed: 0:34:59.
# Training Loss per 20 steps(batches): 0.22372134460601956
# Training Accuracy per 20 steps(batches): 0.93125
# Batch 1500 of 1866.  Elapsed: 0:35:27.
# Training Loss per 20 steps(batches): 0.1394130487984512
# Training Accuracy per 20 steps(batches): 0.95
# Batch 1520 of 1866.  Elapsed: 0:35:56.
# Training Loss per 20 steps(batches): 0.20878472158219666
# Training Accuracy per 20 steps(batches): 0.95
# Batch 1540 of 1866.  Elapsed: 0:36:24.
# Training Loss per 20 steps(batches): 0.14299524389207363
# Training Accuracy per 20 steps(batches): 0.9625
# Batch 1560 of 1866.  Elapsed: 0:36:52.
# Training Loss per 20 steps(batches): 0.19020165554247798
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1580 of 1866.  Elapsed: 0:37:21.
# Training Loss per 20 steps(batches): 0.1657529528136365
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 1600 of 1866.  Elapsed: 0:37:49.
# Training Loss per 20 steps(batches): 0.28841940365964547
# Training Accuracy per 20 steps(batches): 0.925
# Batch 1620 of 1866.  Elapsed: 0:38:17.
# Training Loss per 20 steps(batches): 0.11234961024019867
# Training Accuracy per 20 steps(batches): 0.96875
# Batch 1640 of 1866.  Elapsed: 0:38:46.
# Training Loss per 20 steps(batches): 0.2336532498477027
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1660 of 1866.  Elapsed: 0:39:14.
# Training Loss per 20 steps(batches): 0.22928505606250837
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1680 of 1866.  Elapsed: 0:39:42.
# Training Loss per 20 steps(batches): 0.1749923961935565
# Training Accuracy per 20 steps(batches): 0.95
# Batch 1700 of 1866.  Elapsed: 0:40:11.
# Training Loss per 20 steps(batches): 0.1054514525574632
# Training Accuracy per 20 steps(batches): 0.96875
# Batch 1720 of 1866.  Elapsed: 0:40:39.
# Training Loss per 20 steps(batches): 0.12091564499423839
# Training Accuracy per 20 steps(batches): 0.9625
# Batch 1740 of 1866.  Elapsed: 0:41:07.
# Training Loss per 20 steps(batches): 0.2186833280371502
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1760 of 1866.  Elapsed: 0:41:36.
# Training Loss per 20 steps(batches): 0.22558493320830167
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 1780 of 1866.  Elapsed: 0:42:04.
# Training Loss per 20 steps(batches): 0.25062757070409136
# Training Accuracy per 20 steps(batches): 0.925
# Batch 1800 of 1866.  Elapsed: 0:42:33.
# Training Loss per 20 steps(batches): 0.24807131738052704
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 1820 of 1866.  Elapsed: 0:43:01.
# Training Loss per 20 steps(batches): 0.2430581239052117
# Training Accuracy per 20 steps(batches): 0.94375
# Batch 1840 of 1866.  Elapsed: 0:43:29.
# Training Loss per 20 steps(batches): 0.2430682211765088
# Training Accuracy per 20 steps(batches): 0.9375
# Batch 1860 of 1866.  Elapsed: 0:43:58.
#
# training loss per epoch: 0.22
# training accuracy per epoch: 0.94
# Training 1 epcoh took: 0:44:06

# %%
# test the model on the validation set
def valid(model, validation_loader):
  model.eval()
  val_loss = 0
  nb_val_examples = 0
  n_correct = 0
  with torch.no_grad():
    for _, data in enumerate(validation_loader, 0): 
      ids = data[0].to(device, dtype = torch.long)
      mask = data[1].to(device, dtype = torch.long)
      targets = data[2].to(device, dtype = torch.long)
      outputs = model(ids, mask)
      loss_function = torch.nn.CrossEntropyLoss()
      loss = loss_function(outputs[0], targets)
      val_loss += loss.item()
      big_val, big_idx = torch.max(outputs[0], dim=1)
      n_correct += calcuate_accu(big_idx, targets)
      nb_val_examples+=targets.size(0)

  val_ave_loss = val_loss/len(validation_loader)
  val_accu = (n_correct*100)/nb_val_examples
  print("Loss on validation/test data: %0.2f" % val_ave_loss)
  print("Accuracy on validation/test data: %0.2f%%" % val_accu)
  
  return

# %%
valid(model, validation_dataloader)
# Out:
# Loss on validation/test data: 0.40
# Accuracy on validation/test data: 90.57%

# %%
valid(model, test_dataloader)
# Out:
# Loss on validation/test data: 0.40
# Accuracy on validation/test data: 90.57%

# %%
import os

# Saving best-practices: if you use defaults names for the model, you can reload it using from_pretrained()

output_dir = './Documents/languages_detection_Roberta/saved_roberta_model_and_tokenizer/'

# Create output directory if needed
if not os.path.exists(output_dir):
  os.makedirs(output_dir)

print("Saving model to %s" % output_dir)

# Save a trained model, configuration and tokenizer using `save_pretrained()`.
# They can then be reloaded using `from_pretrained()`
model_to_save = model.module if hasattr(model, 'module') else model  # Take care of distributed/parallel training
model_to_save.save_pretrained(output_dir)
tokenizer.save_pretrained(output_dir)
# Out:
# Saving model to ./Documents/languages_detection_Roberta/saved_roberta_model_and_tokenizer/
# ('./Documents/languages_detection_Roberta/saved_roberta_model_and_tokenizer/tokenizer_config.json',
#  './Documents/languages_detection_Roberta/saved_roberta_model_and_tokenizer/special_tokens_map.json',
#  './Documents/languages_detection_Roberta/saved_roberta_model_and_tokenizer/vocab.json',
#  './Documents/languages_detection_Roberta/saved_roberta_model_and_tokenizer/merges.txt',
#  './Documents/languages_detection_Roberta/saved_roberta_model_and_tokenizer/added_tokens.json')

# %%
df_label = pd.DataFrame(tuple(zip(range(25),LE.classes_)), columns=['id','intent'])
df_label.to_pickle('./Documents/languages_detection_Roberta/saved_roberta_model_and_tokenizer/df_label.pkl')

# %%
# !cp -r ./Documents/languages_detection_Roberta/saved_bert_model_and_tokenizer/ "gdrive/"
# Out:
# cp: cannot stat './Documents/languages_detection_Roberta/saved_bert_model_and_tokenizer/': No such file or directory

# %%
#### load the model and build the detector for deployment
# !pip install transformers
import pandas as pd
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import RobertaModel, RobertaTokenizer
input_dir = '/content/Documents/languages_detection_Roberta/saved_roberta_model_and_tokenizer'

loaded_model = BertForSequenceClassification.from_pretrained(input_dir)
loaded_model.eval()
loaded_tokenizer = RobertaTokenizer.from_pretrained(input_dir)
loaded_df_label = pd.read_pickle('/gdrive/languages_detection_Roberta/saved_roberta_model_and_tokenizer/df_label.pkl')
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.18.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.49)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.5.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-2ac3ebbafdc1> in <module>()
#       9 loaded_model.eval()
#      10 loaded_tokenizer = RobertaTokenizer.from_pretrained(input_dir)
# ---> 11 loaded_df_label = pd.read_pickle('/gdrive/languages_detection_Roberta/saved_roberta_model_and_tokenizer/df_label.pkl')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression, storage_options)
#     199         compression=compression,
#     200         is_text=False,
# --> 201         storage_options=storage_options,
#     202     ) as handles:
#     203
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: '/gdrive/languages_detection_Roberta/saved_roberta_model_and_tokenizer/df_label.pkl'

# %%
def language_identification(intent):

  pt_batch = loaded_tokenizer(
  intent,
  padding=True,
  truncation=True,
  return_tensors="pt")

  pt_outputs = loaded_model(**pt_batch)
  __, id = torch.max(pt_outputs[0], dim=1)
  prediction = loaded_df_label.iloc[[id.item()]]['intent'].item()
  print((prediction))
  return

# %%
input ='اسير تلعب' 
language_identification(input)
# Out:
# arabe

# %%
torch.save(model.state_dict(), 'L_detection_Mmodel_weights.pth')
